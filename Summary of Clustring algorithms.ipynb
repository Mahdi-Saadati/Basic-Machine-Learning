# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahdi-Saadati/Machine-Learning-1/blob/main/Summary%20of%20Clustring%20algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div dir="rtl" align="right">
#
# 🧠 جمع‌بندی خیلی ساده از الگوریتم های خوشه بندی:
#
#
# ![Capture.JPG](data:image/jpeg;base64,...)
