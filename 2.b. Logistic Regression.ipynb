# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahdi-Saadati/Machine-Learning-1/blob/main/2.b.%20Logistic%20Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div dir="rtl" align="right">
#
# 🎯 ایده‌ی مثال
#
# فرض کنید می‌خواهیم ببینیم بر اساس قند خون ناشتا (Fasting Blood Sugar)
# آیا یک فرد دیابت دارد (1) یا ندارد (0).
#
# ما چند داده‌ی فرضی داریم و می‌خواهیم با رگرسیون لجستیک یک مدل بسازیم تا این دو دسته را از هم جدا کند.
#
# ✨ داده‌های فرضی
# ![Capture.JPG](data:image/jpeg;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# -----------------------------
# داده‌ها
X = np.array([80, 90, 100, 110, 120, 130, 140, 150]).reshape(-1, 1)
y = np.array([0, 0, 0, 0, 1, 1, 1, 1])  # 0 = سالم, 1 = دیابت

# -----------------------------
# ساخت و آموزش مدل لجستیک
model = LogisticRegression()
model.fit(X, y)

# پیش‌بینی احتمال دیابت برای همان داده‌ها
y_prob = model.predict_proba(X)[:,1]  # فقط احتمال کلاس 1 (دیابت)
y_pred = model.predict(X)

# -----------------------------
# چاپ نتایج
print("Model prediction:", y_pred) #پیش‌بینی مدل
print("Chance of diabetes:", y_prob) #احتمال دیابت:

# -----------------------------
# رسم نمودار
plt.scatter(X, y, color='blue', label='Real data') #داده‌های واقعی
plt.plot(X, y_prob, color='red', label='Probability of diabetes (model)') #احتمال دیابت (مدل)
plt.xlabel('Fasting blood sugar (mg/dL)') #قند خون ناشتا (mg/dL)
plt.ylabel('Possibility of diabetes') #احتمال دیابت
plt.title('Logistic regression for diabetes prediction') #رگرسیون لجستیک برای پیش‌بینی دیابت
plt.legend()
plt.show()
# Out:
# Model prediction: [0 0 0 0 1 1 1 1]
# Chance of diabetes: [2.55298225e-09 7.28075582e-07 2.07594385e-04 5.59049759e-02
#  9.44094842e-01 9.99792405e-01 9.99999272e-01 9.99999997e-01]

# %% [markdown]
# <div dir="rtl" align="right">
#
# 🔎 چه اتفاقی می‌افتد؟
#
# ✅ نقاط آبی = داده‌های واقعی بیماران
#
# ✅ خط قرمز = خروجی مدل لجستیک که بین 0 و 1 حرکت می‌کند (احتمال دیابت)
#
# ✏️ توضیح ساده
#
# این مدل مثل یک معلم می‌آموزد:
# «اگر قند خون کم باشد، احتمال دیابت کم است (نزدیک 0)»
# و «اگر قند خون زیاد شود، احتمال دیابت زیاد است (نزدیک 1).»
# رگرسیون لجستیک به ما کمک می‌کند یک مرز بین سالم و بیمار پیدا کنیم.
